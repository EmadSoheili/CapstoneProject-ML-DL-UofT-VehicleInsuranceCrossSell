# %%
# Import our dependencies

import pandas as pd
import os
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, balanced_accuracy_score, confusion_matrix
import sklearn as skl
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Load data

df = pd.read_csv(os.path.join('..', 'Resources', 'Created_Files', 'Feature_selected_df.csv'))
df
# Out:
#         Age  Previously_Insured  Vehicle_Damage  Annual_Premium  Vintage  \
# 0        23                   0               1         29648.0       22
# 1        74                   0               1          2630.0       68
# 2        22                   0               1         35674.0      116
# 3        26                   0               0         27920.0      120
# 4        44                   1               0         31630.0      129
# ...     ...                 ...             ...             ...      ...
# 500435   28                   0               1          2630.0      135
# 500436   59                   0               1          2630.0      237
# 500437   33                   1               0         29282.0      273
# 500438   45                   0               1         61984.0      184
# 500439   43                   0               1          2630.0       28
#
#         Response
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 500435         1
# 500436         1
# 500437         1
# 500438         1
# 500439         1
#
# [500440 rows x 6 columns]

# %%
# Define X

X = df.drop(['Response'], axis=1)
X.head(3)
# Out:
#    Age  Previously_Insured  Vehicle_Damage  Annual_Premium  Vintage
# 0   23                   0               1         29648.0       22
# 1   74                   0               1          2630.0       68
# 2   22                   0               1         35674.0      116

# %%
# Define y

y = df['Response']
y.value_counts()
# Out:
# 1    250220
# 0    250220
# Name: Response, dtype: int64

# %%
# Split data into train and test

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Scale the dataset

scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Perceptron

number_input_feature = len(X_train_scaled[0])

nn_model = tf.keras.models.Sequential()

nn_model.add(tf.keras.layers.Dense(units=1, activation='relu', input_dim=number_input_feature))
nn_model.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

nn_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 6
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 8
# Trainable params: 8
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Checkpoint

# Define the checkpoint path

os.makedirs('Checkpoints/', exist_ok=True)
checkpoint_path = 'Checkpoints/Perceptron_weights.{epoch:02d}.hdf5'
cp_callback = ModelCheckpoint(filepath = checkpoint_path, verbose = 1, save_weights_only = True, save_freq = 'epoch', period = 50)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
# Fit the model

start_time = time.time()

fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100, callbacks=[cp_callback])
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)

end_time = time.time()
# Out:
# Epoch 1/100
# 11730/11730 [==============================] - 27s 2ms/step - loss: 0.4967 - accuracy: 0.7740
# Epoch 2/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4555 - accuracy: 0.7855
# Epoch 3/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4536 - accuracy: 0.7855
# Epoch 4/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4531 - accuracy: 0.7855
# Epoch 5/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4528 - accuracy: 0.7855
# Epoch 6/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 7/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 8/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 9/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 10/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 11/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 12/100
# 11730/11730 [==============================] - 26s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 13/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 14/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 15/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 16/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 17/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 18/100
# 11730/11730 [==============================] - 24s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 19/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 20/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 21/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 22/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 23/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 24/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 25/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 26/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 27/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 28/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 29/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 30/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 31/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 32/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 33/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 34/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 35/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 36/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 37/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 38/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 39/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 40/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 41/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 42/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 43/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 44/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 45/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 46/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 47/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 48/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 49/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 50/100
# 11723/11730 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.7854
# Epoch 50: saving model to Checkpoints/Perceptron_weights.50.hdf5
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 51/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 52/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 53/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 54/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 55/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 56/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 57/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 58/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 59/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 60/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 61/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 62/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 63/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 64/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 65/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 66/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 67/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 68/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 69/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 70/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 71/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 72/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 73/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 74/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 75/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 76/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 77/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 78/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 79/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 80/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 81/100
# 11730/11730 [==============================] - 18s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 82/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 83/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4527 - accuracy: 0.7855
# Epoch 84/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 85/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 86/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 87/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 88/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 89/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 90/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 91/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 92/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 93/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 94/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 95/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 96/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 97/100
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 98/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 99/100
# 11730/11730 [==============================] - 20s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# Epoch 100/100
# 11727/11730 [============================>.] - ETA: 0s - loss: 0.4526 - accuracy: 0.7855
# Epoch 100: saving model to Checkpoints/Perceptron_weights.100.hdf5
# 11730/11730 [==============================] - 19s 2ms/step - loss: 0.4526 - accuracy: 0.7855
# 11730/11730 [==============================] - 14s 1ms/step
# 3910/3910 [==============================] - 5s 1ms/step
# 3910/3910 - 4s - loss: 0.4557 - accuracy: 0.7828 - 4s/epoch - 1ms/step

# %%
# Evaluation
                     
elapsed_time  = end_time - start_time

print(f'''Basic Neural Network Performance (Perceptron) Performance

Loss: {round(model_loss*100,2)}%

Accuracy: {round(model_accuracy*100,2)}%

Training Time: {round(elapsed_time,1)} Seconds''')
# Out:
# Basic Neural Network Performance (Perceptron) Performance
#
# Loss: 45.57%
#
# Accuracy: 78.28%
#
# Training Time: 1979.3 Seconds
